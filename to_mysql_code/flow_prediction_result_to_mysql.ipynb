# %%
import pandas as pd
import numpy as np
from datetime import datetime
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()
import os
import sys, urllib, json
import time

# %%
class soda_data_util:
    def __init__(self, file_path, encoding='utf-8'):
        print('========================================开始读取数据========================================')
        # 读取csv表格
        self.csv_data = pd.read_csv(file_path, 
                        encoding = encoding)
        print('==================================数据读取完毕，数据的shape为:'+str(self.csv_data.shape)+"==================================")

# %%
host = '127.0.0.1'
port = 3306
db = 'soda_data_repo'
user = 'root'
password = '19940301'
engine = create_engine(str(r"mysql+mysqldb://%s:" + '%s' + "@%s/%s") % (user, password, host, db))

# %%
top15_predicted_result = '/usr/soda_data_set/experiment_code/flow-prediction/predict8days.csv'
post15_predicted_result = '/usr/soda_data_set/experiment_code/flow-prediction/predict8days2.csv'

start_time = time.time()
#print('文件名：' + top15_predicted_result)
df = soda_data_util(file_path= post15_predicted_result, encoding= 'utf-8').csv_data
print(df.head(10))
df.to_sql('flow_prediction_result_tb', con=engine, if_exists='append', index=False)
end_time = time.time()
print(end_time - start_time)

start_time = time.time()
#print('文件名：' + top15_predicted_result)
df = soda_data_util(file_path= top15_predicted_result, encoding= 'utf-8').csv_data
print(df.head(10))
df.to_sql('flow_prediction_result_tb', con=engine, if_exists='append', index=False)
end_time = time.time()
print(end_time - start_time)
# Out:
# ========================================开始读取数据========================================
# ==================================数据读取完毕，数据的shape为:(226, 26)==================================
#       site date          0    1    2    3         4          5           6  \
# 0  2号线中山公园    0  34.346638  0.0  0.0  0.0  0.142857   0.000000  645.089039
# 1  2号线中山公园    1  27.037567  0.0  0.0  0.0  0.142857   0.000000  489.615895
# 2  2号线中山公园    2  -1.308660  0.0  0.0  0.0  0.142857   0.000000  656.353182
# 3  2号线中山公园    3  -3.543586  0.0  0.0  0.0  0.142857   0.000000  670.038126
# 4  2号线中山公园    4   4.111661  0.0  0.0  0.0  0.142857   0.000000  670.038126
# 5  2号线中山公园    5  -3.459067  0.0  0.0  0.0  0.142857   0.000000  670.038126
# 6  2号线中山公园    6   5.736832  0.0  0.0  0.0  0.142857   0.000000  670.038126
# 7  2号线中山公园    7  32.590478  0.0  0.0  0.0  0.142857   0.000000  670.038126
# 8  2号线中山公园    8  27.094697  0.0  0.0  0.0  0.142857   0.000000  670.038126
# ...

# %%
top15_arima_param = '/usr/soda_data_set/experiment_code/flow-prediction/pqfile.csv'
post15_arima_param = '/usr/soda_data_set/experiment_code/flow-prediction/pqfile2.csv'

start_time = time.time()
#print('文件名：' + top15_predicted_result)
df = soda_data_util(file_path= post15_arima_param, encoding= 'utf-8').csv_data
print(df.head(10))
df.to_sql('flow_prediction_arima_param_tb', con=engine, if_exists='append', index=False)
end_time = time.time()
print(end_time - start_time)

start_time = time.time()
#print('文件名：' + top15_predicted_result)
df = soda_data_util(file_path= top15_arima_param, encoding= 'utf-8').csv_data
print(df.head(10))
df.to_sql('flow_prediction_arima_param_tb', con=engine, if_exists='append', index=False)
end_time = time.time()
print(end_time - start_time)
# Out:
# ========================================开始读取数据========================================
# ==================================数据读取完毕，数据的shape为:(601, 4)==================================
#       site hour pvalue qvalue
# 0  2号线中山公园    0      4      5
# 1  2号线中山公园    1     -1     -1
# 2  2号线中山公园    2     -1     -1
# 3  2号线中山公园    3     -1     -1
# 4  2号线中山公园    4      0      0
# 5  2号线中山公园    5     -1     -1
# 6  2号线中山公园    6      0      3
# 7  2号线中山公园    7     -1     -1
# 8  2号线中山公园    8      5      1
# 9  2号线中山公园    9      5      0
# 0.0783846378326416
# ========================================开始读取数据========================================
# ==================================数据读取完毕，数据的shape为:(360, 4)==================================
#        site  hour  pvalue  qvalue
# 0  2号线虹桥火车站     0       5       0
# 1  2号线虹桥火车站     1       0       0
# 2  2号线虹桥火车站     2      -1      -1
# 3  2号线虹桥火车站     3      -1      -1
# 4  2号线虹桥火车站     4       0       3
# 5  2号线虹桥火车站     5       2       0
# ...
