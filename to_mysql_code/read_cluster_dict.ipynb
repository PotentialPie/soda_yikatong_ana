# %%
import pickle

# %%
pkl_file = open('saved_dict/card_id_dict_47400000.pkl', 'rb')

data1 = pickle.load(pkl_file)

pkl_file.close()

print(len(data1))
# Out:
# 47400000

# %%
for k in data1:
    print(k)
    print(data1[k])
# Out:
# 10119715
# [1, 0, {'1号线徐家汇'}, 0, 0, 0, 1, 0, 0]
# 10143398
# [1, 0, {'1号线中山北路'}, 0, 1, 0, 0, 0, 0]
# 10169424
# [1, 0, {'8号线虹口足球场'}, 0, 0, 0, 0, 1, 0]
# 10208887
# [1, 1, {'1号线富锦路'}, 0, 0, 0, 0, 1, 0]
# 10279354
# [1, 0, {'8号线老西门'}, 0, 0, 0, 0, 1, 0]
# 10360953
# [1, 0, {'2号线东昌路'}, 0, 0, 0, 0, 0, 1]
# 10361441
# [1, 1, {'3号线中山公园'}, 0, 0, 0, 1, 0, 0]
# 10399142
# [1, 0, {'1号线上海火车站'}, 0, 0, 1, 0, 0, 0]
# 10401541
# [1, 0, {'6号线航津路'}, 0, 0, 0, 0, 1, 0]
# 10404688
# [1, 1, {'5号线文井路'}, 0, 0, 0, 1, 0, 0]
# 10421852
# [1, 0, {'2号线南京东路'}, 0, 0, 0, 0, 0, 1]
# 10460799
# [1, 0, {'2号线静安寺'}, 0, 0, 0, 1, 0, 0]
# 10465303
# [1, 0, {'2号线陆家嘴'}, 0, 0, 0, 1, 0, 0]
# 10468023
# [1, 0, {'7号线新村路'}, 0, 0, 0, 1, 0, 0]
# 10503092
# [1, 0, {'1号线人民广场'}, 0, 0, 1, 0, 0, 0]
# 10519227
# [1, 0, {'4号线鲁班路'}, 0, 0, 1, 0, 0, 0]
# 10527616
# [1, 0, {'8号线耀华路'}, 0, 0, 0, 0, 1, 0]
# 10531127
# [1, 1, {'1号线莲花路'}, 0, 0, 0, 0, 1, 0]
# 10531427
# [1, 0, {'6号线博兴路'}, 0, 0, 0, 0, 1, 0]
# 10536142
# ...
